# %%
# 모듈 불러오기
import pandas as pd
import numpy as np
import ast

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor, early_stopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, make_scorer

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
# 데이터 불러오기 1
imdb = pd.read_excel('./imdb_final_6.xlsx', index_col=0)

# 딕셔너리 해제
for i in range(1, 12):
    imdb['season_{}'.format(i)] = imdb.loc[imdb['season_{}'.format(i)].notnull(), 'season_{}'.format(i)].apply(ast.literal_eval)

imdb.tail()
# Out:
#                        korean_title                      english_title  year  \
# Unnamed: 0
# 900                             레일라                              Leila  2019
# 901                     100만 엔의 여인들                  Million Yen Women  2017
# 902                         킬러 코미디언                            Hasmukh  2020
# 903                              달러                             Dollar  2019
# 904         엘리트들, 못다 한 이야기: 나디아 구스만  Elite Short Stories: Nadia Guzmán  2021
#
#             total_season_num  runtime              genre age_rating  \
# Unnamed: 0
# 900                        1       46        드라마, 전쟁, SF         15
# 901                        1       30  스릴러, 범죄, 드라마, 로맨스         19
# 902                        1       33  범죄, 드라마, 스릴러, 코미디         19
# 903                        1       41       액션, 드라마, 로맨스         15
# 904                        1       11           드라마, 로맨스         15
#
#            production_country  total_count  total_rate  ...  season_9  \
# Unnamed: 0                                              ...
# 900                        인도         9300         5.1  ...       NaN
# 901                        일본         2100         7.5  ...       NaN
# 902                        인도         2800         5.4  ...       NaN
# 903                       레바논          651         6.6  ...       NaN
# 904                       스페인         2100         6.2  ...       NaN
#
#             season_10  season_11  \
# Unnamed: 0
# 900               NaN        NaN
# 901               NaN        NaN
# 902               NaN        NaN
# 903               NaN        NaN
# 904               NaN        NaN
#
#                                                      director  \
# Unnamed: 0
# 900           ['Deepa Mehta', 'Pawan Kumar', 'Shanker Raman']
# 901         ['Hiroto Hara', 'Hirotoshi Hara', 'Kenji Kuwaj...
# 902                                      ['Nikhil Gonsalves']
# 903                                      ['Samer Al Barkawi']
# 904                                      ['Dani de la Orden']
#
#                                                        writer  \
# Unnamed: 0
# 900         ['Asad Hussain', 'Deepa Mehta', 'Patrick Graha...
# 901         ['Shunjû Aono', 'Yoshimiko Murooka', 'Yoshitak...
# 902         ['Amogh Ranadive', 'Neeraj Pandey', 'Nikhil Go...
# 903                                          ['Hisham Hilal']
# 904                                        ['Carlos Montero']
#
#                                                         actor  \
# Unnamed: 0
# 900         ['Huma Qureshi', 'Rahul Khanna', 'Siddharth', ...
# 901         ['Yôjirô Noda', 'Rila Fukushima', 'Rena Matsui...
# 902         ['Vir Das', 'Ranvir Shorey', 'Amrita Bagchi', ...
# 903         ['Mark Lewis', 'Adel Karam', 'Amel Bouchoucha'...
# 904         ['Miguel Bernardeau', 'Mina El Hammani', 'Omar...
#
#                                                    imdb_title  \
# Unnamed: 0
# 900                                    Leila (TV Series 2019)
# 901            1000000 yen no Onnatachi (TV Mini Series 2017)
# 902                             Hasmukh (TV Mini Series 2020)
# 903                                   Dollar (TV Series 2019)
# 904         Elite Short Stories: Nadia Guzmán (TV Mini Ser...
#
#                                           imdb_url wins nominations
# Unnamed: 0
# 900          https://www.imdb.com/title/tt9337588/    0           0
# 901          https://www.imdb.com/title/tt6686450/    0           0
# 902          https://www.imdb.com/title/tt9359294/    2           1
# 903         https://www.imdb.com/title/tt10687564/    0           0
# 904         https://www.imdb.com/title/tt14671790/    0           0
#
# [5 rows x 34 columns]

# %%
# 데이터 불러오기 2
watcha = pd.read_excel('./watcha_최종본.xlsx', index_col=0)

# 리스트 해제
for i in range(1, 12):
    watcha['season_{}'.format(i)] = watcha.loc[watcha['season_{}'.format(i)].notnull(), 'season_{}'.format(i)].apply(ast.literal_eval)

watcha.tail()
# Out:
#                 korean_title                      english_title  year  \
# 900                      레일라                              Leila  2019
# 901              100만 엔의 여인들                  Million Yen Women  2017
# 902                  킬러 코미디언                            Hasmukh  2020
# 903                       달러                             Dollar  2019
# 904  엘리트들, 못다 한 이야기: 나디아 구스만  Elite Short Stories: Nadia Guzmán  2021
#
#      total_season_num production_country                  watcha_name  \
# 900                 1                 인도                      ['레일라']
# 901                 1                 일본              ['100만 엔의 여자들']
# 902                 1                 인도                  ['킬러 코미디언']
# 903                 1                레바논                       ['달러']
# 904                 1                스페인  ['엘리트들, 못다 한 이야기: 나디아 구스만']
#
#             season_1 season_2 season_3 season_4 season_5 season_6 season_7  \
# 900     [3.2, 27, 3]      NaN      NaN      NaN      NaN      NaN      NaN
# 901  [3.0, 718, 100]      NaN      NaN      NaN      NaN      NaN      NaN
# 902      [1.6, 4, 0]      NaN      NaN      NaN      NaN      NaN      NaN
# 903      [0.7, 3, 1]      NaN      NaN      NaN      NaN      NaN      NaN
# 904   [2.8, 420, 30]      NaN      NaN      NaN      NaN      NaN      NaN
#
#     season_8 season_9 season_10 season_11
# 900      NaN      NaN       NaN       NaN
# 901      NaN      NaN       NaN       NaN
# 902      NaN      NaN       NaN       NaN
# 903      NaN      NaN       NaN       NaN
# 904      NaN      NaN       NaN       NaN

# %% [markdown]
# ## 2. 함수 만들기

# %% [markdown]
# ### (1) IMDb 평점, 평점 매긴 사람 수

# %%
# IMDb 평점
def get_imdb_rate(x):
    imdb_rate_lst = []

    # 딕셔너리에서 평점 부분만 가져옴
    for idx, val in x.items():
        imdb_rate_lst.append(val[0])

    # 시즌 평점 평균 구하기
    imdb_rate = np.mean(imdb_rate_lst)

    return imdb_rate

# %%
# IMDb 평점 매긴 사람 수
def get_imdb_rate_cnt(x):
    imdb_rate_cnt_lst = []

    # 딕셔너리에서 평점 매긴 사람만 가져옴
    for idx, val in x.items():
        imdb_rate_cnt_lst.append(val[1])


    # 평점을 매긴 사람의 시즌 평균 구하기
    imdb_rate_cnt = np.mean(imdb_rate_cnt_lst)

    return imdb_rate_cnt

# %% [markdown]
# ### (2) 왓챠 평점, 평점을 매긴 사람 수, 리뷰를 쓴 사람 수

# %%
# 왓챠 평점
def get_watcha_rate(x):
    watcha_tmp = x
    watcha_rate = watcha_tmp[0]
    return watcha_rate

# %%
# 왓챠 평점을 매긴 사람 수
def get_watcha_rate_cnt(x):
    watcha_tmp = x
    watcha_rate_cnt = watcha_tmp[1]
    return watcha_rate_cnt

# %%
# 왓챠 리뷰를 쓴 사람 수
def get_watcha_rev_cnt(x):
    watcha_tmp = x
    watcha_rev_cnt = watcha_tmp[2]
    return watcha_rev_cnt

# %% [markdown]
# ### (3) 유지도

# %%
# 평점 유지도
def get_rate_retention(x):
    imdb_tmp = list(x.values())
    k = len(imdb_tmp)
    score = (imdb_tmp[k-1][0] / imdb_tmp[0][0])
    return score

# %%
# 평점 매긴 사람 수의 유지도
def get_rate_cnt_retention(x):
    imdb_tmp = list(x.values())
    k = len(imdb_tmp)
    score = (imdb_tmp[k-1][1] / imdb_tmp[0][1])
    return score

# %% [markdown]
# ### (4) 제작 국가

# %%
# 제작 국가 순위 별 점수 부여
country_scores = {
    "미국": 0.369,
    "대한민국": 0.203,
    "영국": 0.078,
    "스페인": 0.047,
    "멕시코": 0.030,
    "콜롬비아": 0.028,
    "캐나다": 0.024,
    "호주": 0.021,
    "중국": 0.020,
    "프랑스": 0.017,
    "일본": 0.016,
    "브라질": 0.016,
    "독일": 0.015,
    "인도": 0.014,
    "터키": 0.014,
    "이탈리아": 0.013,
    "폴란드": 0.011,
}
# "그 외" 비율
default_score = 0.005
def get_country_score(production_country):
    return country_scores.get(production_country, default_score)

# %% [markdown]
# ### (5) 장르

# %%
# 넷플릭스 장르 선호도 순위 리스트 (선호도 순서대로 정렬)
genres = [
    '드라마', '코미디', 'SF', '액션', '스릴러', '범죄', '공포', '로맨스', '판타지', '전쟁', '서부', '그 외'
]

# 각 장르에 점수를 선형적으로 할당하여 딕셔너리로 만들기
genre_scores = {genre: 1 - i / (len(genres)) for i, genre in enumerate(genres)}

# '그 외'에 해당되는 장르 리스트
other_genres = ['역사', '가족', '음악', 'Made in Europe', '스포츠']

# 장르 문자열을 받아서 점수를 계산하는 함수

def get_genre_score(genre_str):
    # 장르를 ', '로 분리
    genre_list = genre_str.split(', ')
    
    # '그 외'에 포함된 하위 장르가 있는지 확인
    for genre in genre_list:
        if genre in other_genres:
            return genre_scores['그 외']
    
    # 각 장르의 점수의 평균 계산
    total_score = 0
    count = 0
    for genre in genre_list:
        score = genre_scores.get(genre, genre_scores['그 외'])  # 없는 장르는 '그 외' 점수로 처리
        total_score += score
        count += 1
    
    # 평균 점수 계산
    average_score = total_score / count if count > 0 else 0
    return average_score

# %% [markdown]
# ### (6) 장르 다양성 지수

# %%
# 장르 다양성 지수
def get_genre_diversity(x):
    genre_len = len(x.split(', '))
    return genre_len

# %% [markdown]
# ### (7) 연령 등급

# %%
# 연령 등급에 따른 함수
def get_age_rating_score(x):
    if x == 19:
        return 0.5
    elif x == 15:
        return 0.4
    else:
        return 0.1

# %% [markdown]
# ## 3. 최종 모델에 의한 시즌 1 점수 부여

# %%
# 시즌1 점수 부여
for idx, row in imdb.iterrows():
    imdb_tmp = imdb.loc[idx, 'season_1']; watcha_tmp = watcha.loc[idx, 'season_1']
    genre = imdb.loc[idx, 'genre']; country = imdb.loc[idx, 'production_country']; age = imdb.loc[idx, 'age_rating']

    rate = 0.8 * np.log(get_imdb_rate(imdb_tmp)) + 0.2 * np.log(get_watcha_rate(watcha_tmp))
    cnt = 0.8 * np.log(get_imdb_rate_cnt(imdb_tmp)) + 0.2 * np.log(get_watcha_rate_cnt(watcha_tmp))
    ret = 1/4 * np.log(get_rate_retention(imdb_tmp)) + 3/4 * np.log(get_rate_cnt_retention(imdb_tmp))
    info = 0.4 * get_country_score(country) + 0.4 * get_genre_score(genre) + 0.1 * np.log(get_genre_diversity(genre)) + 0.1 * (get_age_rating_score(age))
    total = (0.7 * (0.2 * rate + 0.6 * cnt + 0.2 * ret) + 0.3 * info) * 10

    imdb.loc[idx, 's1_score_final_log'] = total

# %% [markdown]
# ## 4. 시즌 1 점수 확인

# %%
# 시즌 1 점수 상위 20개
imdb[['korean_title', 's1_score_final_log']].sort_values('s1_score_final_log', ascending=False).head(20)
# Out:
#                 korean_title  s1_score_final_log
# Unnamed: 0
# 46                     블랙 미러           50.616271
# 17                   브레이킹 배드           48.220607
# 24                   기묘한 이야기           48.105944
# 7                      워킹 데드           48.072900
# 0                     오징어 게임           46.095135
# 31                        위쳐           45.847324
# 43                     퀸스 갬빗           45.358742
# 42                   베터 콜 사울           45.167963
# 54                       덱스터           44.268580
# 27                  피키 블라인더스           43.611039
# 13                        다크           43.371974
# 63                       원피스           43.363601
# 350               루머의 루머의 루머           43.094496
# 66                 힐 하우스의 유령           42.891346
# 9                        플래시           42.720086
# 20                     마인드헌터           42.327721
# 61               오티스의 비밀 상담소           42.228474
# 59                 하우스 오브 카드           42.064868
# 84                      나르코스           41.993460
# 196         기예르모 델토로의 호기심의 방           41.964257

# %%
# 시즌 1 점수 하위 20개
imdb[['korean_title', 's1_score_final_log']].sort_values('s1_score_final_log', ascending=True).head(20)
# Out:
#                 korean_title  s1_score_final_log
# Unnamed: 0
# 686                   여름의 비밀           10.321210
# 800                   새비지 리듬           10.378955
# 818                      케이지           10.398391
# 119                    컨트리 퀸           10.406179
# 783         체조 아카데미: 두 번째 기회           11.463517
# 681                   타임 허슬러           11.977673
# 784                     매버릭스           12.207123
# 826                     #노필터           12.304023
# 227               앗! 크리스마스라니           12.563415
# 898                 죽음의 타임캡슐           12.654227
# 234                      대리모           12.896751
# 797                스트레인지 스토리           13.616421
# 364                 인생은 오답노트           13.627217
# 613                     자이바!           13.655188
# 749                   여름의 열기           13.755200
# 739                   굿 캅 대니           13.764385
# 400                   마이 런웨이           13.965075
# 813                     파나티코           14.092188
# 162          셰프 치코의 빈자리를 채워라           14.199330
# 810               그녀와 그녀의 그녀           14.305661

# %% [markdown]
# ## 5. 흥행 등급 부여

# %%
# 흥행 등급 부여
imdb['rank'] = pd.qcut((imdb['s1_score_final_log'].rank(pct=True)), q=[0, 0.3, 0.7, 0.95, 1], labels=['부진', '호불호', '흥행', '대흥행'])

# %%
# 흥행 등급 예시
imdb[['korean_title', 's1_score_final_log', 'rank']].head(10)
# Out:
#                   korean_title  s1_score_final_log rank
# Unnamed: 0
# 0                       오징어 게임           46.095135  대흥행
# 1                     12인의 심판자           24.512715  호불호
# 2                       희생자 게임           22.094322   부진
# 3           스위트 투스: 사슴뿔을 가진 소년           36.455354   흥행
# 4                         스위트홈           35.958356   흥행
# 5                          외교관           35.638603   흥행
# 6                         굿 닥터           39.834643  대흥행
# 7                        워킹 데드           48.072900  대흥행
# 8             비르기트: 왕국, 권력, 영광           28.255989  호불호
# 9                          플래시           42.720086  대흥행
